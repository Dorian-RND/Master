# %% [markdown]
# # TP HAC
# #### Dorian RENARD

# %% [markdown]
# ## Exercice 2
#
# Refaire la mêle chose avec le jeu de données iris. Vous avez des instructions pour le chargement des données à cette adresse http://scikit-learn.org/stable/tutorial/basic/tutorial.html (adresse alternative : http://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html).
#
# Une description des données est disponible sur Wikipedia : https://en.wikipedia.org/wiki/Iris_flower_data_set.

# %% [markdown]
# ### Imports and Setup

# %%
# needed imports 
from matplotlib import pyplot as plt 
from scipy.cluster.hierarchy import dendrogram, linkage 
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import scale as scale

# %%
iris = datasets.load_iris()
data = iris.data

# %%
# generate two clusters: a with 100 points, b with 50:
np.random.seed(4711)  # for repeatability of this tutorial
print (data.shape)  # 150 samples with 2 dimensions
plt.scatter(data[:,0], data[:,1])
plt.show()
# Out:
# (150, 4)

# %% [markdown]
# ### Plotting a Dendrogram

# %%
def complete_linkage():
    matriceDist = []
    for i in data:
        ligne = []
        for j in data:
            distance = np.linalg.norm(i-j)
            ligne.append(round(distance,2))
        matriceDist.append(ligne)
    print("                    Matrice de distance:                    \n")
    for line in matriceDist:
        print(line)

# %%
complete_linkage()
# Out:
#                     Matrice de distance:
#
# [0.0, 0.54, 0.51, 0.65, 0.14, 0.62, 0.52, 0.17, 0.92, 0.47, 0.37, 0.37, 0.59, 0.99, 0.88, 1.1, 0.55, 0.1, 0.74, 0.33, 0.44, 0.3, 0.65, 0.47, 0.59, 0.55, 0.32, 0.14, 0.14, 0.54, 0.54, 0.39, 0.62, 0.81, 0.46, 0.37, 0.41, 0.24, 0.87, 0.14, 0.17, 1.35, 0.77, 0.46, 0.62, 0.59, 0.36, 0.58, 0.3, 0.22, 4.0, 3.62, 4.16, 3.09, 3.79, 3.42, 3.79, 2.35, 3.75, 2.89, 2.7, 3.23, 3.15, 3.7, 2.58, 3.63, 3.44, 3.01, 3.77, 2.88, 3.85, 3.08, 4.05, 3.66, 3.42, 3.6, 4.05, 4.24, 3.53, 2.49, 2.82, 2.7, 2.89, 4.14, 3.41, 3.52, 3.91, 3.62, 3.0, 3.02, 3.31, 3.6, 3.01, 2.39, 3.15, 3.07, 3.13, 3.35, 2.09, 3.06, 5.28, 4.21, 5.3, 4.69, 5.06, 6.1, 3.59, 5.64, 5.05, 5.64, 4.36, 4.52, 4.85, 4.19, 4.42, 4.63, 4.65, 6.24, 6.5, 4.14, 5.12, 4.03, 6.21, 4.11, 4.97, 5.31, 3.98, 4.01, 4.84, 5.1, 5.55, 6.01, 4.88, 4.16, 4.57, 5.79, 4.89, 4.61, 3.9, 4.8, 5.02, 4.64, 4.21, 5.26, 5.14, 4.65, 4.28, 4.46, 4.65, 4.14]
# ...

# %%
# generate the linkage matrix
Z = linkage(data, 'ward')

# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
Z2 = linkage(data, 'complete')
# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z2,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
Z3 = linkage(data, 'single')
# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z3,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
Z4 = linkage(data, 'average')
# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z2,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()
